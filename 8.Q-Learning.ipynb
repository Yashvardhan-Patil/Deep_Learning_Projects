# %%
import gymnasium as gym
import numpy as np
import random

# %%
gamma=0.99
epsilon=0.1
alpha=0.5
episodes=500

# %%
Q=np.zeros((48,4))

# %%
#epsilon-policy
def epsilon_greedy(state):
    if random.random()<epsilon:
        return env.action_space.sample()#explore
    else:
        return np.argmax(Q[state])

# %%
#Q-Learning

for episode in range(episodes):
    render=(episode%50==0)

    if render:
        env=gym.make("CliffWalking-v1",render_mode="human")

    else:
        env=gym.make("CliffWalking-v1")

    done=False
    state,_=env.reset()

    total_reward=0
    episode_len=0

    while not done:
        action=epsilon_greedy(state)

        next_state,reward,terminated,truncated,_=env.step(action)
        done=terminated or truncated

        #Q-Learning update
        Q[state,action]+=alpha*(reward + gamma * np.max(Q[next_state])-Q[state,action])
        state=next_state
        total_reward+=reward
        episode_len+=1

    print(f"episode={episode+1}/500 & total rewrad={total_reward} and episode len= {episode_len}")
    env.close()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# episode=1/500 & total rewrad=-135 and episode len= 135
# episode=2/500 & total rewrad=-1916 and episode len= 530
# episode=3/500 & total rewrad=-71 and episode len= 71
# episode=4/500 & total rewrad=-223 and episode len= 124
# episode=5/500 & total rewrad=-283 and episode len= 85
# episode=6/500 & total rewrad=-168 and episode len= 69
# episode=7/500 & total rewrad=-35 and episode len= 35
# episode=8/500 & total rewrad=-212 and episode len= 113
# episode=9/500 & total rewrad=-46 and episode len= 46
# episode=10/500 & total rewrad=-61 and episode len= 61
# episode=11/500 & total rewrad=-50 and episode len= 50
# episode=12/500 & total rewrad=-307 and episode len= 109
# episode=13/500 & total rewrad=-48 and episode len= 48
# episode=14/500 & total rewrad=-38 and episode len= 38
# episode=15/500 & total rewrad=-40 and episode len= 40
# episode=16/500 & total rewrad=-35 and episode len= 35
# episode=17/500 & total rewrad=-28 and episode len= 28
# episode=18/500 & total rewrad=-180 and episode len= 81
# episode=19/500 & total rewrad=-289 and episode len= 91
# episode=20/500 & total rewrad=-29 and episode len= 29
# episode=21/500 & total rewrad=-28 and episode len= 28
# episode=22/500 & total rewrad=-55 and episode len= 55
# episode=23/500 & total rewrad=-21 and episode len= 21
# episode=24/500 & total rewrad=-164 and episode len= 65
# episode=25/500 & total rewrad=-31 and episode len= 31
# episode=26/500 & total rewrad=-28 and episode len= 28
# episode=27/500 & total rewrad=-38 and episode len= 38
# episode=28/500 & total rewrad=-150 and episode len= 51
# episode=29/500 & total rewrad=-17 and episode len= 17
# episode=30/500 & total rewrad=-25 and episode len= 25
# episode=31/500 & total rewrad=-26 and episode len= 26
# episode=32/500 & total rewrad=-135 and episode len= 36
# episode=33/500 & total rewrad=-15 and episode len= 15
# episode=34/500 & total rewrad=-24 and episode len= 24
# episode=35/500 & total rewrad=-13 and episode len= 13
# episode=36/500 & total rewrad=-134 and episode len= 35
# episode=37/500 & total rewrad=-15 and episode len= 15
# episode=38/500 & total rewrad=-144 and episode len= 45
# episode=39/500 & total rewrad=-16 and episode len= 16
# episode=40/500 & total rewrad=-26 and episode len= 26
# episode=41/500 & total rewrad=-121 and episode len= 22
# episode=42/500 & total rewrad=-29 and episode len= 29
# episode=43/500 & total rewrad=-24 and episode len= 24
# episode=44/500 & total rewrad=-13 and episode len= 13
# episode=45/500 & total rewrad=-14 and episode len= 14
# episode=46/500 & total rewrad=-15 and episode len= 15
# episode=47/500 & total rewrad=-21 and episode len= 21
# episode=48/500 & total rewrad=-17 and episode len= 17
# episode=49/500 & total rewrad=-14 and episode len= 14
# episode=50/500 & total rewrad=-28 and episode len= 28
# episode=51/500 & total rewrad=-13 and episode len= 13
# episode=52/500 & total rewrad=-21 and episode len= 21
# episode=53/500 & total rewrad=-13 and episode len= 13
# episode=54/500 & total rewrad=-14 and episode len= 14
# episode=55/500 & total rewrad=-13 and episode len= 13
# episode=56/500 & total rewrad=-13 and episode len= 13
# episode=57/500 & total rewrad=-15 and episode len= 15
# episode=58/500 & total rewrad=-22 and episode len= 22
# episode=59/500 & total rewrad=-14 and episode len= 14
# episode=60/500 & total rewrad=-335 and episode len= 38
# episode=61/500 & total rewrad=-13 and episode len= 13
# episode=62/500 & total rewrad=-15 and episode len= 15
# episode=63/500 & total rewrad=-13 and episode len= 13
# episode=64/500 & total rewrad=-117 and episode len= 18
# episode=65/500 & total rewrad=-13 and episode len= 13
# episode=66/500 & total rewrad=-13 and episode len= 13
# episode=67/500 & total rewrad=-15 and episode len= 15
# episode=68/500 & total rewrad=-13 and episode len= 13
# episode=69/500 & total rewrad=-13 and episode len= 13
# episode=70/500 & total rewrad=-13 and episode len= 13
# episode=71/500 & total rewrad=-13 and episode len= 13
# episode=72/500 & total rewrad=-17 and episode len= 17
# episode=73/500 & total rewrad=-13 and episode len= 13
# episode=74/500 & total rewrad=-13 and episode len= 13
# episode=75/500 & total rewrad=-13 and episode len= 13
# episode=76/500 & total rewrad=-122 and episode len= 23
# episode=77/500 & total rewrad=-15 and episode len= 15
# episode=78/500 & total rewrad=-15 and episode len= 15
# episode=79/500 & total rewrad=-116 and episode len= 17
# episode=80/500 & total rewrad=-13 and episode len= 13
# episode=81/500 & total rewrad=-13 and episode len= 13
# episode=82/500 & total rewrad=-120 and episode len= 21
# episode=83/500 & total rewrad=-13 and episode len= 13
# episode=84/500 & total rewrad=-13 and episode len= 13
# episode=85/500 & total rewrad=-120 and episode len= 21
# episode=86/500 & total rewrad=-13 and episode len= 13
# episode=87/500 & total rewrad=-13 and episode len= 13
# episode=88/500 & total rewrad=-13 and episode len= 13
# episode=89/500 & total rewrad=-14 and episode len= 14
# episode=90/500 & total rewrad=-13 and episode len= 13
# episode=91/500 & total rewrad=-21 and episode len= 21
# episode=92/500 & total rewrad=-13 and episode len= 13
# episode=93/500 & total rewrad=-13 and episode len= 13
# episode=94/500 & total rewrad=-13 and episode len= 13
# episode=95/500 & total rewrad=-136 and episode len= 37
# episode=96/500 & total rewrad=-228 and episode len= 30
# episode=97/500 & total rewrad=-13 and episode len= 13
# episode=98/500 & total rewrad=-119 and episode len= 20
# episode=99/500 & total rewrad=-23 and episode len= 23
# episode=100/500 & total rewrad=-20 and episode len= 20
# episode=101/500 & total rewrad=-113 and episode len= 14
# episode=102/500 & total rewrad=-13 and episode len= 13
# episode=103/500 & total rewrad=-22 and episode len= 22
# episode=104/500 & total rewrad=-125 and episode len= 26
# episode=105/500 & total rewrad=-13 and episode len= 13
# episode=106/500 & total rewrad=-221 and episode len= 23
# episode=107/500 & total rewrad=-13 and episode len= 13
# episode=108/500 & total rewrad=-232 and episode len= 34
# episode=109/500 & total rewrad=-15 and episode len= 15
# episode=110/500 & total rewrad=-124 and episode len= 25
# episode=111/500 & total rewrad=-13 and episode len= 13
# episode=112/500 & total rewrad=-15 and episode len= 15
# episode=113/500 & total rewrad=-16 and episode len= 16
# episode=114/500 & total rewrad=-13 and episode len= 13
# episode=115/500 & total rewrad=-13 and episode len= 13
# episode=116/500 & total rewrad=-13 and episode len= 13
# episode=117/500 & total rewrad=-128 and episode len= 29
# episode=118/500 & total rewrad=-17 and episode len= 17
# episode=119/500 & total rewrad=-120 and episode len= 21
# episode=120/500 & total rewrad=-113 and episode len= 14
# episode=121/500 & total rewrad=-123 and episode len= 24
# episode=122/500 & total rewrad=-13 and episode len= 13
# episode=123/500 & total rewrad=-124 and episode len= 25
# episode=124/500 & total rewrad=-15 and episode len= 15
# episode=125/500 & total rewrad=-15 and episode len= 15
# episode=126/500 & total rewrad=-15 and episode len= 15
# episode=127/500 & total rewrad=-13 and episode len= 13
# episode=128/500 & total rewrad=-13 and episode len= 13
# episode=129/500 & total rewrad=-336 and episode len= 39
# episode=130/500 & total rewrad=-130 and episode len= 31
# episode=131/500 & total rewrad=-13 and episode len= 13
# episode=132/500 & total rewrad=-13 and episode len= 13
# episode=133/500 & total rewrad=-115 and episode len= 16
# episode=134/500 & total rewrad=-13 and episode len= 13
# episode=135/500 & total rewrad=-14 and episode len= 14
# episode=136/500 & total rewrad=-13 and episode len= 13
# episode=137/500 & total rewrad=-15 and episode len= 15
# episode=138/500 & total rewrad=-13 and episode len= 13
# episode=139/500 & total rewrad=-15 and episode len= 15
# episode=140/500 & total rewrad=-15 and episode len= 15
# episode=141/500 & total rewrad=-123 and episode len= 24
# episode=142/500 & total rewrad=-13 and episode len= 13
# episode=143/500 & total rewrad=-15 and episode len= 15
# episode=144/500 & total rewrad=-15 and episode len= 15
# episode=145/500 & total rewrad=-15 and episode len= 15
# episode=146/500 & total rewrad=-13 and episode len= 13
# episode=147/500 & total rewrad=-116 and episode len= 17
# episode=148/500 & total rewrad=-13 and episode len= 13
# episode=149/500 & total rewrad=-23 and episode len= 23
# episode=150/500 & total rewrad=-13 and episode len= 13
# episode=151/500 & total rewrad=-18 and episode len= 18
# episode=152/500 & total rewrad=-125 and episode len= 26
# episode=153/500 & total rewrad=-13 and episode len= 13
# episode=154/500 & total rewrad=-125 and episode len= 26
# episode=155/500 & total rewrad=-13 and episode len= 13
# episode=156/500 & total rewrad=-13 and episode len= 13
# episode=157/500 & total rewrad=-15 and episode len= 15
# episode=158/500 & total rewrad=-13 and episode len= 13
# episode=159/500 & total rewrad=-15 and episode len= 15
# episode=160/500 & total rewrad=-13 and episode len= 13
# episode=161/500 & total rewrad=-13 and episode len= 13
# episode=162/500 & total rewrad=-124 and episode len= 25
# episode=163/500 & total rewrad=-13 and episode len= 13
# episode=164/500 & total rewrad=-13 and episode len= 13
# episode=165/500 & total rewrad=-13 and episode len= 13
# episode=166/500 & total rewrad=-15 and episode len= 15
# episode=167/500 & total rewrad=-20 and episode len= 20
# episode=168/500 & total rewrad=-13 and episode len= 13
# episode=169/500 & total rewrad=-121 and episode len= 22
# episode=170/500 & total rewrad=-125 and episode len= 26
# episode=171/500 & total rewrad=-13 and episode len= 13
# episode=172/500 & total rewrad=-15 and episode len= 15
# episode=173/500 & total rewrad=-15 and episode len= 15
# episode=174/500 & total rewrad=-13 and episode len= 13
# episode=175/500 & total rewrad=-13 and episode len= 13
# episode=176/500 & total rewrad=-17 and episode len= 17
# episode=177/500 & total rewrad=-20 and episode len= 20
# episode=178/500 & total rewrad=-13 and episode len= 13
# episode=179/500 & total rewrad=-17 and episode len= 17
# episode=180/500 & total rewrad=-13 and episode len= 13
# episode=181/500 & total rewrad=-113 and episode len= 14
# episode=182/500 & total rewrad=-120 and episode len= 21
# episode=183/500 & total rewrad=-13 and episode len= 13
# episode=184/500 & total rewrad=-13 and episode len= 13
# episode=185/500 & total rewrad=-20 and episode len= 20
# episode=186/500 & total rewrad=-15 and episode len= 15
# episode=187/500 & total rewrad=-13 and episode len= 13
# episode=188/500 & total rewrad=-117 and episode len= 18
# episode=189/500 & total rewrad=-117 and episode len= 18
# episode=190/500 & total rewrad=-116 and episode len= 17
# episode=191/500 & total rewrad=-17 and episode len= 17
# episode=192/500 & total rewrad=-124 and episode len= 25
# episode=193/500 & total rewrad=-13 and episode len= 13
# episode=194/500 & total rewrad=-13 and episode len= 13
# episode=195/500 & total rewrad=-13 and episode len= 13
# episode=196/500 & total rewrad=-15 and episode len= 15
# episode=197/500 & total rewrad=-15 and episode len= 15
# episode=198/500 & total rewrad=-333 and episode len= 36
# episode=199/500 & total rewrad=-15 and episode len= 15
# episode=200/500 & total rewrad=-17 and episode len= 17
# episode=201/500 & total rewrad=-14 and episode len= 14
# episode=202/500 & total rewrad=-117 and episode len= 18
# episode=203/500 & total rewrad=-15 and episode len= 15
# episode=204/500 & total rewrad=-13 and episode len= 13
# episode=205/500 & total rewrad=-23 and episode len= 23
# episode=206/500 & total rewrad=-13 and episode len= 13
# episode=207/500 & total rewrad=-13 and episode len= 13
# episode=208/500 & total rewrad=-13 and episode len= 13
# episode=209/500 & total rewrad=-13 and episode len= 13
# episode=210/500 & total rewrad=-19 and episode len= 19
# episode=211/500 & total rewrad=-13 and episode len= 13
# episode=212/500 & total rewrad=-13 and episode len= 13
# episode=213/500 & total rewrad=-15 and episode len= 15
# episode=214/500 & total rewrad=-116 and episode len= 17
# episode=215/500 & total rewrad=-227 and episode len= 29
# episode=216/500 & total rewrad=-15 and episode len= 15
# episode=217/500 & total rewrad=-15 and episode len= 15
# episode=218/500 & total rewrad=-226 and episode len= 28
# episode=219/500 & total rewrad=-15 and episode len= 15
# episode=220/500 & total rewrad=-15 and episode len= 15
# episode=221/500 & total rewrad=-16 and episode len= 16
# episode=222/500 & total rewrad=-19 and episode len= 19
# episode=223/500 & total rewrad=-14 and episode len= 14
# episode=224/500 & total rewrad=-15 and episode len= 15
# episode=225/500 & total rewrad=-13 and episode len= 13
# episode=226/500 & total rewrad=-13 and episode len= 13
# episode=227/500 & total rewrad=-13 and episode len= 13
# episode=228/500 & total rewrad=-15 and episode len= 15
# episode=229/500 & total rewrad=-13 and episode len= 13
# episode=230/500 & total rewrad=-13 and episode len= 13
# episode=231/500 & total rewrad=-15 and episode len= 15
# episode=232/500 & total rewrad=-13 and episode len= 13
# episode=233/500 & total rewrad=-13 and episode len= 13
# episode=234/500 & total rewrad=-14 and episode len= 14
# episode=235/500 & total rewrad=-113 and episode len= 14
# episode=236/500 & total rewrad=-16 and episode len= 16
# episode=237/500 & total rewrad=-15 and episode len= 15
# episode=238/500 & total rewrad=-13 and episode len= 13
# episode=239/500 & total rewrad=-19 and episode len= 19
# episode=240/500 & total rewrad=-19 and episode len= 19
# episode=241/500 & total rewrad=-20 and episode len= 20
# episode=242/500 & total rewrad=-13 and episode len= 13
# episode=243/500 & total rewrad=-13 and episode len= 13
# episode=244/500 & total rewrad=-15 and episode len= 15
# episode=245/500 & total rewrad=-13 and episode len= 13
# episode=246/500 & total rewrad=-126 and episode len= 27
# episode=247/500 & total rewrad=-16 and episode len= 16
# episode=248/500 & total rewrad=-17 and episode len= 17
# episode=249/500 & total rewrad=-13 and episode len= 13
# episode=250/500 & total rewrad=-132 and episode len= 33
# episode=251/500 & total rewrad=-15 and episode len= 15
# episode=252/500 & total rewrad=-13 and episode len= 13
# episode=253/500 & total rewrad=-17 and episode len= 17
# episode=254/500 & total rewrad=-235 and episode len= 37
# episode=255/500 & total rewrad=-15 and episode len= 15
# episode=256/500 & total rewrad=-13 and episode len= 13
# episode=257/500 & total rewrad=-15 and episode len= 15
# episode=258/500 & total rewrad=-13 and episode len= 13
# episode=259/500 & total rewrad=-13 and episode len= 13
# episode=260/500 & total rewrad=-23 and episode len= 23
# episode=261/500 & total rewrad=-15 and episode len= 15
# episode=262/500 & total rewrad=-128 and episode len= 29
# episode=263/500 & total rewrad=-13 and episode len= 13
# episode=264/500 & total rewrad=-119 and episode len= 20
# episode=265/500 & total rewrad=-13 and episode len= 13
# episode=266/500 & total rewrad=-124 and episode len= 25
# episode=267/500 & total rewrad=-13 and episode len= 13
# episode=268/500 & total rewrad=-17 and episode len= 17
# episode=269/500 & total rewrad=-113 and episode len= 14
# episode=270/500 & total rewrad=-118 and episode len= 19
# episode=271/500 & total rewrad=-13 and episode len= 13
# episode=272/500 & total rewrad=-13 and episode len= 13
# episode=273/500 & total rewrad=-126 and episode len= 27
# episode=274/500 & total rewrad=-13 and episode len= 13
# episode=275/500 & total rewrad=-13 and episode len= 13
# episode=276/500 & total rewrad=-15 and episode len= 15
# episode=277/500 & total rewrad=-113 and episode len= 14
# episode=278/500 & total rewrad=-15 and episode len= 15
# episode=279/500 & total rewrad=-15 and episode len= 15
# episode=280/500 & total rewrad=-19 and episode len= 19
# episode=281/500 & total rewrad=-13 and episode len= 13
# episode=282/500 & total rewrad=-121 and episode len= 22
# episode=283/500 & total rewrad=-18 and episode len= 18
# episode=284/500 & total rewrad=-14 and episode len= 14
# episode=285/500 & total rewrad=-116 and episode len= 17
# episode=286/500 & total rewrad=-15 and episode len= 15
# episode=287/500 & total rewrad=-13 and episode len= 13
# episode=288/500 & total rewrad=-13 and episode len= 13
# episode=289/500 & total rewrad=-13 and episode len= 13
# episode=290/500 & total rewrad=-18 and episode len= 18
# episode=291/500 & total rewrad=-17 and episode len= 17
# episode=292/500 & total rewrad=-13 and episode len= 13
# episode=293/500 & total rewrad=-127 and episode len= 28
# episode=294/500 & total rewrad=-336 and episode len= 39
# episode=295/500 & total rewrad=-15 and episode len= 15
# episode=296/500 & total rewrad=-17 and episode len= 17
# episode=297/500 & total rewrad=-13 and episode len= 13
# episode=298/500 & total rewrad=-13 and episode len= 13
# episode=299/500 & total rewrad=-127 and episode len= 28
# episode=300/500 & total rewrad=-15 and episode len= 15
# episode=301/500 & total rewrad=-116 and episode len= 17
# episode=302/500 & total rewrad=-15 and episode len= 15
# episode=303/500 & total rewrad=-15 and episode len= 15
# episode=304/500 & total rewrad=-15 and episode len= 15
# episode=305/500 & total rewrad=-17 and episode len= 17
# episode=306/500 & total rewrad=-13 and episode len= 13
# episode=307/500 & total rewrad=-14 and episode len= 14
# episode=308/500 & total rewrad=-13 and episode len= 13
# episode=309/500 & total rewrad=-13 and episode len= 13
# episode=310/500 & total rewrad=-15 and episode len= 15
# episode=311/500 & total rewrad=-13 and episode len= 13
# episode=312/500 & total rewrad=-17 and episode len= 17
# episode=313/500 & total rewrad=-15 and episode len= 15
# episode=314/500 & total rewrad=-226 and episode len= 28
# episode=315/500 & total rewrad=-17 and episode len= 17
# episode=316/500 & total rewrad=-13 and episode len= 13
# episode=317/500 & total rewrad=-119 and episode len= 20
# episode=318/500 & total rewrad=-13 and episode len= 13
# episode=319/500 & total rewrad=-15 and episode len= 15
# episode=320/500 & total rewrad=-14 and episode len= 14
# episode=321/500 & total rewrad=-15 and episode len= 15
# episode=322/500 & total rewrad=-15 and episode len= 15
# episode=323/500 & total rewrad=-16 and episode len= 16
# episode=324/500 & total rewrad=-17 and episode len= 17
# episode=325/500 & total rewrad=-13 and episode len= 13
# episode=326/500 & total rewrad=-15 and episode len= 15
# episode=327/500 & total rewrad=-15 and episode len= 15
# episode=328/500 & total rewrad=-122 and episode len= 23
# episode=329/500 & total rewrad=-17 and episode len= 17
# episode=330/500 & total rewrad=-13 and episode len= 13
# episode=331/500 & total rewrad=-20 and episode len= 20
# episode=332/500 & total rewrad=-13 and episode len= 13
# episode=333/500 & total rewrad=-15 and episode len= 15
# episode=334/500 & total rewrad=-13 and episode len= 13
# episode=335/500 & total rewrad=-13 and episode len= 13
# episode=336/500 & total rewrad=-15 and episode len= 15
# episode=337/500 & total rewrad=-23 and episode len= 23
# episode=338/500 & total rewrad=-14 and episode len= 14
# episode=339/500 & total rewrad=-13 and episode len= 13
# episode=340/500 & total rewrad=-15 and episode len= 15
# episode=341/500 & total rewrad=-330 and episode len= 33
# episode=342/500 & total rewrad=-121 and episode len= 22
# episode=343/500 & total rewrad=-13 and episode len= 13
# episode=344/500 & total rewrad=-17 and episode len= 17
# episode=345/500 & total rewrad=-13 and episode len= 13
# episode=346/500 & total rewrad=-115 and episode len= 16
# episode=347/500 & total rewrad=-231 and episode len= 33
# episode=348/500 & total rewrad=-17 and episode len= 17
# episode=349/500 & total rewrad=-122 and episode len= 23
# episode=350/500 & total rewrad=-13 and episode len= 13
# episode=351/500 & total rewrad=-129 and episode len= 30
# episode=352/500 & total rewrad=-14 and episode len= 14
# episode=353/500 & total rewrad=-13 and episode len= 13
# episode=354/500 & total rewrad=-15 and episode len= 15
# episode=355/500 & total rewrad=-13 and episode len= 13
# episode=356/500 & total rewrad=-13 and episode len= 13
# episode=357/500 & total rewrad=-14 and episode len= 14
# episode=358/500 & total rewrad=-13 and episode len= 13
# episode=359/500 & total rewrad=-13 and episode len= 13
# episode=360/500 & total rewrad=-118 and episode len= 19
# episode=361/500 & total rewrad=-122 and episode len= 23
# episode=362/500 & total rewrad=-13 and episode len= 13
# episode=363/500 & total rewrad=-13 and episode len= 13
# episode=364/500 & total rewrad=-130 and episode len= 31
# episode=365/500 & total rewrad=-19 and episode len= 19
# episode=366/500 & total rewrad=-13 and episode len= 13
# episode=367/500 & total rewrad=-13 and episode len= 13
# episode=368/500 & total rewrad=-15 and episode len= 15
# episode=369/500 & total rewrad=-13 and episode len= 13
# episode=370/500 & total rewrad=-17 and episode len= 17
# episode=371/500 & total rewrad=-14 and episode len= 14
# episode=372/500 & total rewrad=-15 and episode len= 15
# episode=373/500 & total rewrad=-13 and episode len= 13
# episode=374/500 & total rewrad=-13 and episode len= 13
# episode=375/500 & total rewrad=-15 and episode len= 15
# episode=376/500 & total rewrad=-13 and episode len= 13
# episode=377/500 & total rewrad=-15 and episode len= 15
# episode=378/500 & total rewrad=-125 and episode len= 26
# episode=379/500 & total rewrad=-121 and episode len= 22
# episode=380/500 & total rewrad=-119 and episode len= 20
# episode=381/500 & total rewrad=-117 and episode len= 18
# episode=382/500 & total rewrad=-14 and episode len= 14
# episode=383/500 & total rewrad=-13 and episode len= 13
# episode=384/500 & total rewrad=-13 and episode len= 13
# episode=385/500 & total rewrad=-19 and episode len= 19
# episode=386/500 & total rewrad=-13 and episode len= 13
# episode=387/500 & total rewrad=-17 and episode len= 17
# episode=388/500 & total rewrad=-113 and episode len= 14
# episode=389/500 & total rewrad=-15 and episode len= 15
# episode=390/500 & total rewrad=-15 and episode len= 15
# episode=391/500 & total rewrad=-113 and episode len= 14
# episode=392/500 & total rewrad=-129 and episode len= 30
# episode=393/500 & total rewrad=-122 and episode len= 23
# episode=394/500 & total rewrad=-13 and episode len= 13
# episode=395/500 & total rewrad=-17 and episode len= 17
# episode=396/500 & total rewrad=-13 and episode len= 13
# episode=397/500 & total rewrad=-13 and episode len= 13
# episode=398/500 & total rewrad=-13 and episode len= 13
# episode=399/500 & total rewrad=-124 and episode len= 25
# episode=400/500 & total rewrad=-13 and episode len= 13
# episode=401/500 & total rewrad=-13 and episode len= 13
# episode=402/500 & total rewrad=-15 and episode len= 15
# episode=403/500 & total rewrad=-13 and episode len= 13
# episode=404/500 & total rewrad=-15 and episode len= 15
# episode=405/500 & total rewrad=-13 and episode len= 13
# episode=406/500 & total rewrad=-125 and episode len= 26
# episode=407/500 & total rewrad=-19 and episode len= 19
# episode=408/500 & total rewrad=-17 and episode len= 17
# episode=409/500 & total rewrad=-127 and episode len= 28
# episode=410/500 & total rewrad=-217 and episode len= 19
# episode=411/500 & total rewrad=-15 and episode len= 15
# episode=412/500 & total rewrad=-13 and episode len= 13
# episode=413/500 & total rewrad=-123 and episode len= 24
# episode=414/500 & total rewrad=-125 and episode len= 26
# episode=415/500 & total rewrad=-115 and episode len= 16
# episode=416/500 & total rewrad=-129 and episode len= 30
# episode=417/500 & total rewrad=-13 and episode len= 13
# episode=418/500 & total rewrad=-13 and episode len= 13
# episode=419/500 & total rewrad=-121 and episode len= 22
# episode=420/500 & total rewrad=-120 and episode len= 21
# episode=421/500 & total rewrad=-116 and episode len= 17
# episode=422/500 & total rewrad=-135 and episode len= 36
# episode=423/500 & total rewrad=-15 and episode len= 15
# episode=424/500 & total rewrad=-15 and episode len= 15
# episode=425/500 & total rewrad=-13 and episode len= 13
# episode=426/500 & total rewrad=-13 and episode len= 13
# episode=427/500 & total rewrad=-15 and episode len= 15
# episode=428/500 & total rewrad=-13 and episode len= 13
# episode=429/500 & total rewrad=-17 and episode len= 17
# episode=430/500 & total rewrad=-16 and episode len= 16
# episode=431/500 & total rewrad=-115 and episode len= 16
# episode=432/500 & total rewrad=-113 and episode len= 14
# episode=433/500 & total rewrad=-17 and episode len= 17
# episode=434/500 & total rewrad=-115 and episode len= 16
# episode=435/500 & total rewrad=-13 and episode len= 13
# episode=436/500 & total rewrad=-15 and episode len= 15
# episode=437/500 & total rewrad=-13 and episode len= 13
# episode=438/500 & total rewrad=-13 and episode len= 13
# episode=439/500 & total rewrad=-17 and episode len= 17
# episode=440/500 & total rewrad=-226 and episode len= 28
# episode=441/500 & total rewrad=-13 and episode len= 13
# episode=442/500 & total rewrad=-13 and episode len= 13
# episode=443/500 & total rewrad=-647 and episode len= 53
# episode=444/500 & total rewrad=-19 and episode len= 19
# episode=445/500 & total rewrad=-13 and episode len= 13
# episode=446/500 & total rewrad=-13 and episode len= 13
# episode=447/500 & total rewrad=-237 and episode len= 39
# episode=448/500 & total rewrad=-17 and episode len= 17
# episode=449/500 & total rewrad=-13 and episode len= 13
# episode=450/500 & total rewrad=-124 and episode len= 25
# episode=451/500 & total rewrad=-332 and episode len= 35
# episode=452/500 & total rewrad=-121 and episode len= 22
# episode=453/500 & total rewrad=-117 and episode len= 18
# episode=454/500 & total rewrad=-19 and episode len= 19
# episode=455/500 & total rewrad=-13 and episode len= 13
# episode=456/500 & total rewrad=-113 and episode len= 14
# episode=457/500 & total rewrad=-13 and episode len= 13
# episode=458/500 & total rewrad=-119 and episode len= 20
# episode=459/500 & total rewrad=-15 and episode len= 15
# episode=460/500 & total rewrad=-13 and episode len= 13
# episode=461/500 & total rewrad=-19 and episode len= 19
# episode=462/500 & total rewrad=-13 and episode len= 13
# episode=463/500 & total rewrad=-15 and episode len= 15
# episode=464/500 & total rewrad=-117 and episode len= 18
# episode=465/500 & total rewrad=-13 and episode len= 13
# episode=466/500 & total rewrad=-125 and episode len= 26
# episode=467/500 & total rewrad=-13 and episode len= 13
# episode=468/500 & total rewrad=-330 and episode len= 33
# episode=469/500 & total rewrad=-15 and episode len= 15
# episode=470/500 & total rewrad=-13 and episode len= 13
# episode=471/500 & total rewrad=-13 and episode len= 13
# episode=472/500 & total rewrad=-123 and episode len= 24
# episode=473/500 & total rewrad=-13 and episode len= 13
# episode=474/500 & total rewrad=-13 and episode len= 13
# episode=475/500 & total rewrad=-13 and episode len= 13
# episode=476/500 & total rewrad=-13 and episode len= 13
# episode=477/500 & total rewrad=-13 and episode len= 13
# episode=478/500 & total rewrad=-18 and episode len= 18
# episode=479/500 & total rewrad=-13 and episode len= 13
# episode=480/500 & total rewrad=-126 and episode len= 27
# episode=481/500 & total rewrad=-17 and episode len= 17
# episode=482/500 & total rewrad=-13 and episode len= 13
# episode=483/500 & total rewrad=-13 and episode len= 13
# episode=484/500 & total rewrad=-128 and episode len= 29
# episode=485/500 & total rewrad=-15 and episode len= 15
# episode=486/500 & total rewrad=-15 and episode len= 15
# episode=487/500 & total rewrad=-15 and episode len= 15
# episode=488/500 & total rewrad=-15 and episode len= 15
# episode=489/500 & total rewrad=-122 and episode len= 23
# episode=490/500 & total rewrad=-13 and episode len= 13
# episode=491/500 & total rewrad=-13 and episode len= 13
# episode=492/500 & total rewrad=-22 and episode len= 22
# episode=493/500 & total rewrad=-13 and episode len= 13
# episode=494/500 & total rewrad=-17 and episode len= 17
# episode=495/500 & total rewrad=-13 and episode len= 13
# episode=496/500 & total rewrad=-14 and episode len= 14
# episode=497/500 & total rewrad=-13 and episode len= 13
# episode=498/500 & total rewrad=-117 and episode len= 18
# episode=499/500 & total rewrad=-15 and episode len= 15
# episode=500/500 & total rewrad=-15 and episode len= 15

# %%
env = gym.make("CliffWalking-v1", render_mode="human")
state, _ = env.reset()
total_reward = 0
epsiode_len = 0
done = False

while not done:
    action = np.argmax(Q[state])
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated

    epsiode_len += 1
    total_reward += reward

print(f"total reward = {total_reward} & epsiode len = {epsiode_len}")
env.close()
# Out:
# total reward = -13 & epsiode len = 13

# %%
Q[36]
# Out:
# array([ -12.2478977 , -112.12540735,  -13.1254182 ,  -13.12531457])
